# %% [markdown]
# # Module 11: Introduction to Machine Learning
#
# ## Topics:
# 1. ML types (Supervised, Unsupervised, Reinforcement)
# 2. Train/Val/Test split
# 3. Bias-Variance tradeoff
# 4. Overfitting vs Underfitting
#
# **Start your ML journey!**
