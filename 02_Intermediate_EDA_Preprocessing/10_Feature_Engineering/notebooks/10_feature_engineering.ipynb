# %% [markdown]
# # Module 10: Feature Engineering Fundamentals
#
# ## Topics:
# 1. Creating new features
# 2. Encoding categorical variables
# 3. Scaling & normalization
# 4. Feature selection basics
#
# **Features make or break models!**
