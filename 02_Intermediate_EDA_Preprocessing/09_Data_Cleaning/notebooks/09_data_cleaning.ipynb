# %% [markdown]
# # Module 09: Data Cleaning Masterclass
#
# ## Topics:
# 1. Missing values (10+ techniques)
# 2. Outlier detection & handling
# 3. Duplicate removal
# 4. Data type corrections
# 5. Text cleaning
#
# **Clean data = Good models!**
