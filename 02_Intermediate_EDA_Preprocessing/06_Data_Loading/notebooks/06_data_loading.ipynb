# %% [markdown]
# # Module 06: Data Loading & Initial Exploration
#
# ## Topics:
# 1. Loading CSV, Excel, JSON, SQL
# 2. Initial data inspection
# 3. Data types & memory optimization
# 4. Handling large datasets
#
# **Real-world data loading!**
