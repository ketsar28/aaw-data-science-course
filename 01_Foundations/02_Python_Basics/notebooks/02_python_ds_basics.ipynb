# %% [markdown]
# # Module 02: Python for Data Science - Advanced Basics
#
# ## Topics:
# 1. List/Dict/Set Comprehensions
# 2. Lambda, Map, Filter, Reduce
# 3. File I/O (CSV, JSON)
# 4. Error Handling
# 5. OOP Basics for DS
#
# **All in Bahasa Indonesia!**
