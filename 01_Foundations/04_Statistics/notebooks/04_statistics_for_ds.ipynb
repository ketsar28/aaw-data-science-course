# %% [markdown]
# # Module 04: Statistics for Data Science
#
# ## Topics:
# 1. Descriptive Statistics
# 2. Probability Basics
# 3. Distributions (Normal, Binomial, etc)
# 4. Hypothesis Testing
# 5. Correlation & Causation
#
# **Statistics foundation untuk ML!**
