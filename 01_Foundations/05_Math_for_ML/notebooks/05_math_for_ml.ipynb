# %% [markdown]
# # Module 05: Mathematics for Machine Learning
#
# ## Topics:
# 1. Linear Algebra (Vectors, Matrices)
# 2. Calculus Basics (Derivatives, Gradients)
# 3. Optimization Fundamentals
#
# **Math essentials untuk understand ML!**
