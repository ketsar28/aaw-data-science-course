# %% [markdown]
# # Module 03: NumPy & Pandas Fundamentals
#
# ## Topics:
# 1. NumPy Arrays & Operations
# 2. Pandas DataFrames
# 3. Data Loading & Basic Operations
# 4. Indexing & Slicing
# 5. GroupBy & Aggregations
#
# **Foundation libraries untuk Data Science!**
